# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ny_post = pd.read_csv('/content/gdrive/MyDrive/Cendie/NY-Post.csv')

# %%
ny_times = pd.read_csv('/content/gdrive/MyDrive/Cendie/NY-Times.csv')

# %%
ny_post.head(2)
# Out:
#        Date Assigned to  ... Unnamed: 18 Unnamed: 19
# 0  3/1/2020     Cecilia  ...         NaN         NaN
# 1  3/1/2020     Cecilia  ...         NaN         NaN
#
# [2 rows x 20 columns]

# %%
ny_times.head(5)
# Out:
#         Date Assigned to  ... Abstractor Unnamed: 10
# 0  1/19/2020           A  ...    AM, NR          NaN
# 1  1/26/2020           A  ...        NaN         NaN
# 2  1/26/2020           A  ...        NaN         NaN
# 3  1/26/2020           A  ...        NaN         NaN
# 4  1/26/2020           A  ...        NaN         NaN
#
# [5 rows x 11 columns]
